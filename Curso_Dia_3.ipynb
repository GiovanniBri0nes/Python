# %% [markdown]
# # Dia 3
#
# ## Temario
# - Listas
# - Tuplas
# - Sets
# - Diccionarios

# %% [markdown]
# # Estructuras de datos
# Las estructuras de datos son formas de organizar informacion para trabajar con ellas de manera eficiente.
#
# - Listas -> ordenadas, modificadas, permiten duplicados
# - Tuplas -> ordenadas, inmutables, permiten duplicados
# - Sets -> no son ordenados, no se permiten duplicados
# - Diccionarios -> pares por clave:valor
#
# Nota:
# - Pilas (FILO - First In Last Out)
# - Colas (FIFO - Fist In First Out)
# - Listas enlazadaso o doblemente enlazadas

# %% [markdown]
# ## Listas
# Las listas son colecciones ordenadas que podemos modificar y almacenan elementos de distintos tipos de datos.

# %%
lista_de_compras = ["manzanas", "pan", "leche", "huevos", "mantequilla", "queso", "jamon"]
print(lista_de_compras)
#
# Out:
# ['manzanas', 'pan', 'leche', 'huevos', 'mantequilla', 'queso', 'jamon']

# %%
print(lista_de_compras[6])
# Out:
# jamon

# %%
# Agregar elemento a la lista  .append()
lista_de_compras.append("sopa")
print(lista_de_compras)
# Out:
# ['manzanas', 'pan', 'leche', 'huevos', 'mantequilla', 'queso', 'jamon', 'sopa']

# %%
# Agregar un elemento en una posicion
lista_de_compras.insert(1, "platano")
print(lista_de_compras)
# Out:
# ['manzanas', 'platano', 'platano', 'platano', 'pan', 'leche', 'huevos', 'mantequilla', 'queso', 'jamon', 'sopa']

# %%
# Para eliminar un elemento de una lista existe el remove y el pop
lista_de_compras.remove("platano")
print(lista_de_compras)
# Out:
# ['manzanas', 'platano', 'platano', 'pan', 'leche', 'huevos', 'mantequilla', 'queso', 'jamon', 'sopa']

# %%
# Existen 2 formas de usar el pop
lista_de_compras.pop() # sin nada dentro del parentesis borra el ultimo elemento
lista_de_compras.pop(2) # borra el elemento de la posicion que quieras
print(lista_de_compras)
# Nota: retorna el numero eliminado
# Out:
# ['manzanas', 'platano', 'pan', 'leche', 'huevos', 'mantequilla', 'queso', 'jamon']

# %%
# Podemos recorrer el arreglo por medio de un for
for elementos in lista_de_compras:
  print(elementos)
# Out:
# manzanas
# platano
# pan
# leche
# huevos
# mantequilla
# queso
# jamon

# %%
# len() saca el tamaño de la lista
print(len(lista_de_compras))
for i in range(len(lista_de_compras)):
  print(f"{i + 1} - {lista_de_compras[i]}")
# Out:
# 8
# 1 - manzanas
# 2 - platano
# 3 - pan
# 4 - leche
# 5 - huevos
# 6 - mantequilla
# 7 - queso
# 8 - jamon

# %%
promedios = [55.6, 97.5, 23.6, 97.5, 72.4, 100]
print(promedios)
promedios.sort() # sort() sirve para ordenar la lista de manera ascendente
print(promedios)
# ordenar una lista de manera descendente
promedios.sort(reverse = True)
print(promedios)
# Out:
# [55.6, 97.5, 23.6, 97.5, 72.4, 100]
# [23.6, 55.6, 72.4, 97.5, 97.5, 100]
# [100, 97.5, 97.5, 72.4, 55.6, 23.6]

# %%
# Podemos ingresar al ultimo elemento de una lista
print(promedios[-1])
# Out:
# 23.6

# %%
# Encontrar el mayor y el menor de una lista
print(max(promedios))
print(min(promedios))
# Out:
# 100
# 23.6

# %%
# Declaracion y uso de matrices
calificaciones = [[100, 88, 93], [99, 56, 72]]
i = 1
for cali_i in calificaciones:
  print(f"\n Alumno {i}")
  j = 1
  for cali_j in cali_i:
    print(f" Cali {j}: {cali_j}")
    j += 1
  j = 0
  i += 1
# Out:
#  Alumno 1
#  Cali 1: 100
#  Cali 2: 88
#  Cali 3: 93
#
#  Alumno 2
#  Cali 1: 99
#  Cali 2: 56
#  Cali 3: 72
# [[100, 88, 93], [99, 56, 72]]

# %% [markdown]
# # Tuplas
# Son colecciones ordenadas pero inmutables

# %%
# Hagamos un programa donde guardemos fechas de nacimiento de un grupo en una tupla
fechas = ("10/10/05", "22/03/02", "17/04/04", "25/02/04")
fechas
# Out:
# ('10/10/05', '22/03/02', '17/04/04', '25/02/04')

# %%
# ES INMUTABLE
fechas.append("10/06/03")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2807552834.py in <cell line: 0>()
#       1 # ES INMUTABLE
# ----> 2 fechas.append("10/06/03")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
# Convertir tupla en lista
fecha_lista = list(fechas) # Ya se pueden usar los comandos basicos de una lista

# %% [markdown]
# ## Sets
# Los sets son colecciones sin orden y que no permiten elementos duplicados

# %%
nombre = {"Angel", "Eliud", "Diana", "Juan", "Juan"}
print(nombre)
print(type(nombre))
# Out:
# {'Eliud', 'Diana', 'Angel', 'Juan'}
# <class 'set'>

# %%
distintos_datos = {"Angel", 1, "Diana", "Juan", 4.8}
distintos_datos
# Out:
# {1, 4.8, 'Angel', 'Diana', 'Juan'}

# %%
# Agregar add()
nombre.add("Leonardo")
nombre
# Out:
# {'Angel', 'Diana', 'Eliud', 'Juan', 'Leonardo'}

# %%
print(nombre[2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1064476624.py in <cell line: 0>()
# ----> 1 print(nombre[2])
#
# TypeError: 'set' object is not subscriptable

# %%
nombre[2] = "Axel"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-441675753.py in <cell line: 0>()
# ----> 1 nombre[2] = "Axel"
#
# TypeError: 'set' object does not support item assignment

# %%
# union
matutino = {20322, 22183, 123123, 53234}
vespertino = {20322,11111, 123124, 53236}
total_matriculas = matutino.union(vespertino)
print(total_matriculas)
total_matriculas = matutino | (vespertino)
print(total_matriculas)
# Out:
# {20322, 22183, 11111, 53234, 123123, 53236, 123124}
# {20322, 22183, 11111, 53234, 123123, 53236, 123124}

# %%
# interseccion
ca = {1234, 121, 646, 12414, 73434, 124124, 675234}
al = {1234, 111, 222, 333, 444}
ca_al = ca.intersection(al)
print(ca_al)
ca_al = ca & al
print(ca_al)
# Out:
# {1234}
# {1234}

# %%
# diferencia
solo_calculo = ca.difference(al)
print(solo_calculo)
solo_calculo = ca - al
print(solo_calculo)
# Out:
# {675234, 646, 121, 73434, 124124, 12414}
# {675234, 646, 121, 73434, 124124, 12414}

# %%
nombre = {"Angel", "Eliud", "Diana", "Juan", "Juan"}
#remove, pop
nombre.remove("Angel")
print(nombre)
nombre.pop()
print(nombre)
# Out:
# {'Eliud', 'Diana', 'Juan'}
# {'Diana', 'Juan'}

# %%
# Eliminar todo el set
nombre.clear()
nombre
# Out:
# set()

# %% [markdown]
# ## Diccionarios
# Los diccionarios son colecciones no ordenadas de pares clave:valor

# %%
alumno = {
    "nombre": "Giovanni Briones",
    "edad": 21,
    "carrera": "LMAD",
    "semestre": 8,
    "promedio": 88,
    "calificaciones": [100, 94, 94, 97, 100]
}
print(type(alumno))
alumno
# Out:
# <class 'dict'>
# {'nombre': 'Giovanni Briones',
#  'edad': 21,
#  'carrera': 'LMAD',
#  'semestre': 8,
#  'promedio': 88,
#  'calificaciones': [100, 94, 94, 97, 100]}

# %%
print("El alumno ", alumno["nombre"], " esta estudiando ", alumno["carrera"])
# Out:
# El alumno  Giovanni Briones  esta estudiando  LMAD

# %%
# Agregar al diccionario
alumno["area preferida"] = "Soporte TI"
alumno
# Out:
# {'nombre': 'Giovanni Briones',
#  'edad': 21,
#  'carrera': 'LMAD',
#  'semestre': 8,
#  'promedio': 88,
#  'calificaciones': [100, 94, 94, 97, 100],
#  'area preferida': 'Soporte TI'}

# %%
for valor in alumno:
  print(alumno[valor])
# Out:
# Giovanni Briones
# 21
# LMAD
# 8
# 88
# [100, 94, 94, 97, 100]
# Soporte TI

# %%
for clave, valor in alumno.items(): # devuelve una vista de todos los pares clave:valor del diccionario
  print(clave, ":", valor)
# Out:
# nombre : Giovanni Briones
# edad : 21
# carrera : LMAD
# semestre : 8
# promedio : 88
# calificaciones : [100, 94, 94, 97, 100]
# area preferida : Soporte TI

# %%
# El metodo .clear() tambien se puede usar en los diccionarios
# Tenemos el .get que nos ayuda a obtener el valor de cierta clave
print(alumno.get("nombre"))
# Out:
# Giovanni Briones

# %%
alumno_1 = alumno.items()
print(alumno_1)
print(type(alumno_1))
alumno_lista = list(alumno_1)
print(alumno_lista)
print(type(alumno_lista))
#
# Out:
# dict_items([('nombre', 'Giovanni Briones'), ('edad', 21), ('carrera', 'LMAD'), ('semestre', 8), ('promedio', 88), ('calificaciones', [100, 94, 94, 97, 100]), ('area preferida', 'Soporte TI')])
# <class 'dict_items'>
# [('nombre', 'Giovanni Briones'), ('edad', 21), ('carrera', 'LMAD'), ('semestre', 8), ('promedio', 88), ('calificaciones', [100, 94, 94, 97, 100]), ('area preferida', 'Soporte TI')]
# <class 'list'>

# %%
# El metodo .values() sirve para obtener los valores del diccionario tambien se puede usar en la interaccion
alumno_v = alumno.values()
print(type(alumno_v))
alumno_v
# Out:
# <class 'dict_values'>
# dict_values(['Giovanni Briones', 21, 'LMAD', 8, 88, [100, 94, 94, 97, 100], 'Soporte TI'])

# %%
if "carrera" in alumno:
  print("Existe carrera")
else:
  print("No existe carrera")

if("dinero") in alumno:
  print("Alumno tiene dinero")
else:
  print("Alumno no tiene dinero")
# Out:
# Existe carrera
# Alumno no tiene dinero

# %%
# .copy() copia todo el diccionario en una nueva variable
# .update() -> sirve para cambiar los valores
alumno.update({"semestre": 7})
alumno
# Out:
# {'nombre': 'Giovanni Briones',
#  'edad': 21,
#  'carrera': 'LMAD',
#  'semestre': 7,
#  'promedio': 88,
#  'calificaciones': [100, 94, 94, 97, 100],
#  'area preferida': 'Soporte TI'}
